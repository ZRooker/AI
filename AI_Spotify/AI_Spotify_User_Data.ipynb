# %%
import os
import json
#!pip install spotipy
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
#The Goal: 
# A supervised learning algorithm, such as a decision tree or support vector machine, 
# could be used to classify the genre of music based on the data provided. 
# The algorithm would be trained on a dataset of labeled music genres and the associated data values, 
# and then it could be used to predict the genre of music given a new set of data values.

cid ='d8762235995b4ddcbc0df90739df9a63' # Client ID; copy this from your app created on beta.developer.spotify.com
secret = '887a4eccdbde4195bfc0f7f4c472fe70' # Client Secret; copy this from your app
username = '12155311349' # Your Spotify username

#for avaliable scopes see https://developer.spotify.com/web-api/using-scopes/
scope = 'user-library-read playlist-modify-public playlist-read-private'

redirect_uri='https://localhost:8080/callback/'

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret) 

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

token = util.prompt_for_user_token(username,scope,client_id=cid,client_secret=secret,redirect_uri="https://localhost:8080/callback/")

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)
# URL https://localhost:8080/callback/?code=AQCitDypZlzg4HjphjFbgplsoM-avYD0-FL_xwfRLO24oW5Ra612Yk_F-vYDYADG-wO-o-XwZtqc9Zu8ygq51UzsKHV1ewtZUr_p8HscNLHbVQNAsMlCCcQB3_pt73G0DKAlYLBlGRdLWUdonKKQD6ue3-Q--FfkOLCB6bUsfANfXskihfsMVhciJM-xcXQZ8LPN
top_50 = []
if token:
    sp = spotipy.Spotify(auth=token)
    results = sp.current_user_top_tracks(limit=50,offset=0,time_range='medium_term')
    print(results)
#     for i in range(0, len(results)):
#         if results[i]['track']['id'] != None: # Removes the local tracks in your playlist if there is any
#             track_ids.append(results[i]['track']['id'])
#             track_names.append(results[i]['track']['name'])
#             album.append(results[i]['track']['album']['name'])
#             artist.append(results[i]['track']['artists'][0]['name'])
else:
    print("Can't get token for", username)
    
df = pd.DataFrame(results) 
df
# Out:
# {'items': [{'album': {'album_type': 'SINGLE', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2mVVjNmdjXZZDvhgQWiakk'}, 'href': 'https://api.spotify.com/v1/artists/2mVVjNmdjXZZDvhgQWiakk', 'id': '2mVVjNmdjXZZDvhgQWiakk', 'name': 'Khruangbin', 'type': 'artist', 'uri': 'spotify:artist:2mVVjNmdjXZZDvhgQWiakk'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3qnGvpP8Yth1AqSBMqON5x'}, 'href': 'https://api.spotify.com/v1/artists/3qnGvpP8Yth1AqSBMqON5x', 'id': '3qnGvpP8Yth1AqSBMqON5x', 'name': 'Leon Bridges', 'type': 'artist', 'uri': 'spotify:artist:3qnGvpP8Yth1AqSBMqON5x'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/4HFO9PDRxsdbcegkcNhxgz'}, 'href': 'https://api.spotify.com/v1/albums/4HFO9PDRxsdbcegkcNhxgz', 'id': '4HFO9PDRxsdbcegkcNhxgz', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273ff26bd277274b27f249cc638', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02ff26bd277274b27f249cc638', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851ff26bd277274b27f249cc638', 'width': 64}], 'name': 'Texas Sun', 'release_date': '2020-02-07', 'release_date_precision': 'day', 'total_tracks': 4, 'type': 'album', 'uri': 'spotify:album:4HFO9PDRxsdbcegkcNhxgz'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2mVVjNmdjXZZDvhgQWiakk'}, 'href': 'https://api.spotify.com/v1/artists/2mVVjNmdjXZZDvhgQWiakk', 'id': '2mVVjNmdjXZZDvhgQWiakk', 'name': 'Khruangbin', 'type': 'artist', 'uri': 'spotify:artist:2mVVjNmdjXZZDvhgQWiakk'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3qnGvpP8Yth1AqSBMqON5x'}, 'href': 'https://api.spotify.com/v1/artists/3qnGvpP8Yth1AqSBMqON5x', 'id': '3qnGvpP8Yth1AqSBMqON5x', 'name': 'Leon Bridges', 'type': 'artist', 'uri': 'spotify:artist:3qnGvpP8Yth1AqSBMqON5x'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA'], 'disc_number': 1, 'duration_ms': 252811, 'explicit': False, 'external_ids': {'isrc': 'USJ5G1921401'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/24ntSW3QVJzR79lHAAOTaY'}, 'href': 'https://api.spotify.com/v1/tracks/24ntSW3QVJzR79lHAAOTaY', 'id': '24ntSW3QVJzR79lHAAOTaY', 'is_local': False, 'name': 'Texas Sun', 'popularity': 73, 'preview_url': 'https://p.scdn.co/mp3-preview/dade042c75e63121fcc870d777ae83864cd01382?cid=d8762235995b4ddcbc0df90739df9a63', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:24ntSW3QVJzR79lHAAOTaY'}, {'album': {'album_type': 'ALBUM', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0iEtIxbK0KxaSlF7G42ZOp'}, 'href': 'https://api.spotify.com/v1/artists/0iEtIxbK0KxaSlF7G42ZOp', 'id': '0iEtIxbK0KxaSlF7G42ZOp', 'name': 'Metro Boomin', 'type': 'artist', 'uri': 'spotify:artist:0iEtIxbK0KxaSlF7G42ZOp'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'I ...
#                                                 items  total  limit  offset  \
# 0   {'album': {'album_type': 'SINGLE', 'artists': ...     50     50       0
# 1   {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 2   {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 3   {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 4   {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 5   {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 6   {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 7   {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 8   {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 9   {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 10  {'album': {'album_type': 'SINGLE', 'artists': ...     50     50       0
# 11  {'album': {'album_type': 'SINGLE', 'artists': ...     50     50       0
# 12  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 13  {'album': {'album_type': 'SINGLE', 'artists': ...     50     50       0
# 14  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 15  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 16  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 17  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 18  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 19  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 20  {'album': {'album_type': 'SINGLE', 'artists': ...     50     50       0
# 21  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 22  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 23  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 24  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 25  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 26  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 27  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 28  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 29  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 30  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 31  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 32  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 33  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 34  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 35  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 36  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 37  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 38  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 39  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 40  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 41  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 42  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 43  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 44  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 45  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 46  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 47  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 48  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
# 49  {'album': {'album_type': 'ALBUM', 'artists': [...     50     50       0
#
#                                                  href  next previous
# 0   https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 1   https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 2   https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 3   https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 4   https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 5   https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 6   https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 7   https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 8   https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 9   https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 10  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 11  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 12  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 13  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 14  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 15  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 16  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 17  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 18  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 19  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 20  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 21  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 22  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 23  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 24  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 25  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 26  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 27  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 28  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 29  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 30  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 31  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 32  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 33  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 34  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 35  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 36  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 37  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 38  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 39  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 40  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 41  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 42  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 43  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 44  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 45  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 46  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 47  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 48  https://api.spotify.com/v1/me/top/tracks?limit...  None     None
# 49  https://api.spotify.com/v1/me/top/tracks?limit...  None     None

# %%
#Creating function and having user give PlaylistID, and genre (0 = counrty, 1 = rock...)
def input_playlist(playlistID, genre): 

    playlist = sp.user_playlist(username, playlistID);

    tracks = playlist["tracks"];
    songs = tracks["items"];
    total_tracks = tracks["total"]
    
#     # Iterate over all tracks in the playlist using offset to get beyond the first 100 tracks
    for i in range(100, total_tracks, 100):
        tracks = sp.user_playlist_tracks(username, playlistID, offset=i)
        songs += tracks["items"]
        
    #Putting Track ID, Track Name, Album, and artist name in matrix's

    track_ids = [] 
    track_names = []
    album = []
    artist =[]

    #Getting Track Data
    for i in range(0, len(songs)):
        if songs[i]['track']['id'] != None: # Removes the local tracks in your playlist if there is any
            track_ids.append(songs[i]['track']['id'])
            track_names.append(songs[i]['track']['name'])
            album.append(songs[i]['track']['album']['name'])
            artist.append(songs[i]['track']['artists'][0]['name'])

    features = []
    for i in range(0,len(songs)):
        audio_features = sp.audio_features(track_ids[i])
        for track in audio_features:

          if track is None:
            print(track)
            features.append({'danceability': 0, 'energy': 0, 'key': 0, 'loudness': 0, 'mode': 0, 'speechiness': 0, 'acousticness': 0, 'instrumentalness': 0, 'liveness': 0, 'valence': 0, 'tempo': 0, 'type': 'audio_features', 'id': '00000', 'uri': 'spotify:track:0', 'track_href': 'https://api.spotify.com/', 'analysis_url': 'https://api.spotify.com/', 'duration_ms': 0, 'time_signature': 0})
          else:
            features.append(track)

    #Creating our DataFrames
    df = pd.DataFrame(features, index = track_names) 

    #Adding a new column
    df['genre'] = genre #Country
    df['Song Title'] = track_names
    df['Artist'] = artist

    # Scale between 0 and 1
    df["key"] = (df["key"] / df["key"].max())
    df["tempo"] = (df["tempo"] / df["tempo"].max())
    df["loudness"] = (df["loudness"] / df["loudness"].min())
    
#     #calculate the IQR for instrumentalness and acousticness
    Q1 = df["instrumentalness"].quantile(0.25)
    Q3 = df["instrumentalness"].quantile(0.75)
    IQR = Q3 - Q1
    
    Q12 = df["acousticness"].quantile(0.25)
    Q32 = df["acousticness"].quantile(0.75)
    IQR2 = Q32 - Q12
    
#     #Remove rows with outliers
    df = df[~((df["instrumentalness"] < (df["instrumentalness"].quantile(0.25) - 1.5 * IQR)) | (df["instrumentalness"] > (df["instrumentalness"].quantile(0.75) + 1.5 * IQR)))]
    df = df[~((df["acousticness"] < (df["acousticness"].quantile(0.25) - 1.5 * IQR2)) | (df["acousticness"] > (df["acousticness"].quantile(0.75) + 1.5 * IQR2)))]
    
#     Q1 = df.quantile(0.25)
#     Q3 = df.quantile(0.75)
#     IQR = Q3 - Q1
#     df = df[~((df.sub(Q1, axis=1).div(IQR, axis=1)).lt(-1.5) | (df.sub(Q1, axis=1).div(IQR, axis=1)).gt(1.5)).any(axis=1)]
    return df
